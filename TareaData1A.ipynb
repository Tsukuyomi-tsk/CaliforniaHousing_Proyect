# %%
# Instalar todas las librerías necesarias para el notebook
# !pip install pandas selenium matplotlib openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.2)
# Requirement already satisfied: selenium in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.35.0)
# Requirement already satisfied: matplotlib in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.6)
# Requirement already satisfied: openpyxl in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (2025.8.3)
# Requirement already satisfied: typing_extensions~=4.14.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: et-xmlfile in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.30.0->selenium) (3.10)
# Requirement already satisfied: outcome in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio~=0.30.0->selenium) (2.0.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.23)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\sigli\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\sigli\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By 
import matplotlib.pyplot as plt

# %%
base_url = "https://nextspaceflight.com/launches/past/"
last_page = 2  # 239 el total
def scrape_details(browser, url): 
    browser.get(url)
    details_grid = browser.find_elements(By.CLASS_NAME, "mdl-grid.a")[1]  
    details = details_grid.text 
    browser.back()
    return details

# %%
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument("--headless")  # Ejecutar en modo headless (sin abrir una ventana del navegador)
browser = webdriver.Chrome(options=options) # generamos un navegador automatizado

launch_data = []
for page in range(1, last_page + 1):  
    browser.get(f"{base_url}?page={page}") # obtenemos el html (hace la petición), sin selenium sería la librería de requests
    cards = browser.find_elements(By.CLASS_NAME, "mdl-card")
    for card in cards:
        company = card.find_element(By.CLASS_NAME, "mdl-card__title-text").text # type() -> string
        rocket_and_payload = card.find_element(By.CLASS_NAME, "header-style").text # type() -> string
        date_and_location = card.find_element(By.CLASS_NAME, "mdl-card__supporting-text").text # type() -> string
        details_url = card.find_element(By.CLASS_NAME, "mdc-button").get_attribute("href") # type() -> string
        details = scrape_details(browser, details_url)
        launch_dict = {'company': company, 
                    'rocket_and_payload': rocket_and_payload, 
                    'date_and_location': date_and_location, 
                    'details_url': details_url,
                       'details': details}
        launch_data.append(launch_dict)
    
browser.quit()

df = pd.DataFrame(launch_data, columns=['company', 'rocket_and_payload', 'date_and_location', 'details_url', 'details'])

# %%
#Diccionario para extraer los datos de details
def parse_details(details_text):
    details_dict = {}
    for line in details_text.split('\n'):
        if ':' in line:
            key, value = line.split(':', 1)
            details_dict[key.strip()] = value.strip()
    return details_dict

# %%
#Creamos columnas nuev columnas nuevas automáticamente
details_expanded = df['details'].apply(parse_details).apply(pd.Series)
df = pd.concat([df, details_expanded], axis=1)

# %%
# Reemplazar NaN, None o 0 por el promedio de cada columna relevante
import re
import numpy as np
def extraer_numero(payload):
    if isinstance(payload, str):
        match = re.search(r'(\d+[\,\.]?\d*)', payload.replace(',', '.'))
        if match:
            try:
                return float(match.group(1))
            except:
                return np.nan
    if payload is None:
        return np.nan
    return payload if isinstance(payload, (int, float)) else np.nan

# Eliminar columnas duplicadas si existen
df = df.loc[:,~df.columns.duplicated()]

#de aqui en adelantev es IA GitHub Copilot

# Extraer y limpiar columnas numéricas
for col in ['Rocket Height', 'Fairing diameter', 'Fairing Height', 'Payload to LEO', 'Payload to GTO']:
    if col in df.columns:
        df[col+'_num'] = df[col].apply(extraer_numero)

# Mostrar antes de reemplazar

for col in ['Rocket Height_num', 'Fairing diameter_num', 'Fairing Height_num', 'Payload to LEO_num', 'Payload to GTO_num']:
    if col in df.columns:
        print(col, df[col].head())

# Reemplazar 0, NaN o None por el promedio de la columna para todas excepto Fairing diameter y Fairing Height
for col in ['Rocket Height_num', 'Payload to LEO_num', 'Payload to GTO_num']:
    if col in df.columns:
        vals = df[col].replace(0, np.nan)
        mean = vals.mean(skipna=True)
        df[col] = vals.fillna(mean)

# Para Fairing diameter y Fairing Height: solo reemplazar NaN por el promedio (no los ceros)
for col in ['Fairing diameter_num', 'Fairing Height_num']:
    if col in df.columns:
        vals = df[col]
        mean = vals.mean(skipna=True)
        df[col] = vals.fillna(mean)

# Mostrar después de reemplazar
print('Después de reemplazar NaN:')
for col in ['Rocket Height_num', 'Fairing diameter_num', 'Fairing Height_num', 'Payload to LEO_num', 'Payload to GTO_num']:
    if col in df.columns:
        print(col, df[col].head())

# Asignar columnas limpias a nombres estándar para el cálculo
df['LEO_kg'] = df['Payload to LEO_num'] if 'Payload to LEO_num' in df.columns else 0
df['GTO_kg'] = df['Payload to GTO_num'] if 'Payload to GTO_num' in df.columns else 0

df['Payload_total_kg'] = df['LEO_kg'] + df['GTO_kg']

# Calcular solo el volumen total del cohete usando las columnas correctas
def volumen_total(row):
    diam = row['Fairing diameter_num'] if 'Fairing diameter_num' in row and not np.isnan(row['Fairing diameter_num']) else 0
    altura_cono = row['Fairing Height_num'] if 'Fairing Height_num' in row and not np.isnan(row['Fairing Height_num']) else 0
    altura_total = row['Rocket Height_num'] if 'Rocket Height_num' in row and not np.isnan(row['Rocket Height_num']) else 0
    altura_cil = altura_total - altura_cono if altura_total > altura_cono else 0
    if diam > 0 and (altura_cil > 0 or altura_cono > 0):
        vol_cil = np.pi * (diam/2)**2 * altura_cil
        vol_cono = (1/3) * np.pi * (diam/2)**2 * altura_cono
        return vol_cil + vol_cono
    return 0

df['Volumen_total_m3'] = df.apply(volumen_total, axis=1)

# Eliminar columnas intermedias de volumen y auxiliares si existen
df.drop(columns=["details", "Payload to LEO", "Payload to GTO", "Volumen_cilindro_m3", "Volumen_cono_m3", 'Rocket Height_num', 'Fairing diameter_num', 'Fairing Height_num', 'Payload to LEO_num', 'Payload to GTO_num'], inplace=True, errors='ignore')
df
# Out:
# Rocket Height_num 0    70.00
# 1    51.38
# 2    70.00
# 3    58.00
# 4    31.00
# Name: Rocket Height_num, dtype: float64
# Fairing Height_num 0    13.00
# 1    15.59
# 2    13.00
# 3    12.40
# 4      NaN
# Name: Fairing Height_num, dtype: float64
# Payload to LEO_num 0    22.8
# 1     7.5
# 2    22.8
# 3    12.0
# 4     1.5
# Name: Payload to LEO_num, dtype: float64
# Payload to GTO_num 0    8.3
# 1    0.0
# 2    8.3
# 3    7.0
# 4    NaN
# Name: Payload to GTO_num, dtype: float64
# Después de reemplazar NaN:
# Rocket Height_num 0    70.00
# 1    51.38
# 2    70.00
# 3    58.00
# 4    31.00
# Name: Rocket Height_num, dtype: float64
# Fairing Height_num 0    13.000000
# 1    15.590000
# 2    13.000000
# 3    12.400000
# 4    10.959038
# Name: Fairing Height_num, dtype: float64
# Payload to LEO_num 0    22.8
# 1     7.5
# 2    22.8
# 3    12.0
# 4     1.5
# Name: Payload to LEO_num, dtype: float64
# Payload to GTO_num 0    8.300000
# 1    7.260077
# 2    8.300000
# 3    7.000000
# 4    7.260077
# Name: Payload to GTO_num, dtype: float64
#             company                                 rocket_and_payload  \
# 0            SpaceX                  Falcon 9 Block 5 | Nusantara Lima
# 1         Roscosmos                        Soyuz 2.1a | Progress MS-32
# 2            SpaceX     Falcon 9 Block 5 | Tranche 1 Transport Layer B
# 3              CASC                          Long March 7A | Yaogan 45
# 4       Chinarocket           Jielong 3 | Geely Constellation Group 05
# 5            SpaceX             Falcon 9 Block 5 | Starlink Group 17-9
# 6              CASC                 Long March 6A | Yaogan 40 Group 03
# 7            SpaceX            Falcon 9 Block 5 | Starlink Group 10-57
# 8   Galactic Energy                             Ceres 1 | 3 satellites
# 9              CASC                     Long March 3C/YZ-1 | Shiyan 29
# 10           SpaceX            Falcon 9 Block 5 | Starlink Group 10-22
# 11           SpaceX             Falcon 9 Block 5 | Starlink Group 17-8
# 12              IAI                                 Shavit 2 | Ofek-19
# 13           SpaceX            Falcon 9 Block 5 | Starlink Group 10-14
# 14           SpaceX             Falcon 9 Block 5 | Starlink Group 17-7
# 15           SpaceX            Falcon 9 Block 5 | Starlink Group 10-11
# 16           SpaceX            Falcon 9 Block 5 | Starlink Group 10-56
# 17           SpaceX       Starship-Super Heavy v2 | Starship Flight 10
# 18           SpaceX        Falcon 9 Block 5 | NAOS (LUXEOSys) & Others
# 19             CASC                Long March 8A | SatNet LEO Group 10
# 20           SpaceX                      Falcon 9 Block 5 | CRS SpX-33
# 21       Rocket Lab               Electron/Curie | Live, Laugh, Launch
# 22           SpaceX             Falcon 9 Block 5 | Starlink Group 17-6
# 23           SpaceX                 Falcon 9 Block 5 | USSF-36 (OTV-8)
# 24           VKS RF                  Angara 1.2 | Cosmos 2590-2593 (?)
# 25        Roscosmos                            Soyuz 2.1b | Bion-M n°2
# 26        CAS Space                          Kinetica 1 | 7 satellites
# 27           SpaceX             Falcon 9 Block 5 | Starlink Group 17-5
# 28             CASC                Long March 6A | SatNet LEO Group 09
# 29             CASC                     Long March 4C | Shiyan 28 B-02
# 30        Landspace                        ZhuQue-2E | Unknown Payload
# 31           SpaceX            Falcon 9 Block 5 | Starlink Group 10-20
# 32           SpaceX             Falcon 9 Block 5 | Starlink Group 17-4
# 33             CASC           Long March 5B/YZ-2 | SatNet LEO Group 08
# 34              ULA           Vulcan VC4S | USSF-106 (NTS-3 & USA-554)
# 35      Arianespace                            Ariane 62 | METOP-SG A1
# 36           SpaceX          Falcon 9 Block 5 | Project Kuiper (KF-02)
# 37      Chinarocket           Jielong 3 | Geely Constellation Group 04
# 38       Rocket Lab       Electron/Curie | The Harvest Goddess Thrives
# 39             CASC                Long March 12 | SatNet LEO Group 07
# 40           SpaceX            Falcon 9 Block 5 | Starlink Group 10-30
# 41      Blue Origin                                New Shepard | NS-34
# 42           SpaceX                  Falcon 9 Block 5 | SpaceX Crew-11
# 43           SpaceX  Falcon 9 Block 5 | Starlink Group 13-4, USA 54...
# 44           ExPace                              Kuaizhou 1A | PRSC-S1
# 45             ISRO                                 GSLV Mk II | NISAR
# 46             CASC                Long March 8A | SatNet LEO Group 06
# 47           SpaceX            Falcon 9 Block 5 | Starlink Group 10-29
# 48          Gilmour                                 Eris | TestFlight1
# 49           iSpace                           Hyperbola 1 | Kunpeng-03
# 50             CASC                Long March 6A | SatNet LEO Group 05
# 51           SpaceX             Falcon 9 Block 5 | Starlink Group 17-2
# 52           SpaceX            Falcon 9 Block 5 | Starlink Group 10-26
# 53      Arianespace                          Vega C | CO3D & MicroCarb
# 54        Roscosmos           Soyuz 2.1b/Fregat-M | Ionosfera-M n°3, 4
# 55           SpaceX                Falcon 9 Block 5 | TRACERS & Others
# 56           SpaceX               Falcon 9 Block 5 | O3b mPOWER 9 & 10
# 57           SpaceX             Falcon 9 Block 5 | Starlink Group 17-3
# 58           SpaceX          Falcon 9 Block 5 | Project Kuiper (KF-01)
# 59           SpaceX             Falcon 9 Block 5 | Starlink Group 15-2
#
#                                     date_and_location  \
# 0   Thu Sep 11, 2025 22:56 CLST\nSLC-40, Cape Cana...
# 1   Thu Sep 11, 2025 12:54 CLST\nSite 31/6, Baikon...
# 2   Wed Sep 10, 2025 11:12 CLST\nSLC-4E, Vandenber...
# 3   Mon Sep 8, 2025 23:00 CLST\nLC-201, Wenchang S...
# 4   Mon Sep 8, 2025 16:48 CLST\nOriental Spaceport...
# 5   Sat Sep 6, 2025 2:06 PM CLT\nSLC-4E, Vandenber...
# 6   Sat Sep 6, 2025 12:34 PM CLT\nLC-9A, Taiyuan S...
# 7   Fri Sep 5, 2025 8:32 AM CLT\nLC-39A, Kennedy S...
# 8   Fri Sep 5, 2025 7:39 AM CLT\nSite 95A, Jiuquan...
# 9   Thu Sep 4, 2025 10:34 PM CLT\nLC-2, Xichang Sa...
# 10  Wed Sep 3, 2025 7:56 AM CLT\nSLC-40, Cape Cana...
# 11  Tue Sep 2, 2025 11:51 PM CLT\nSLC-4E, Vandenbe...
# 12  Tue Sep 2, 2025 3:30 PM CLT\nPad 1, Palmachim ...
# 13  Sun Aug 31, 2025 7:49 AM CLT\nSLC-40, Cape Can...
# 14  Sat Aug 30, 2025 12:59 AM CLT\nSLC-4E, Vandenb...
# 15  Thu Aug 28, 2025 4:12 AM CLT\nLC-39A, Kennedy ...
# 16  Wed Aug 27, 2025 7:10 AM CLT\nSLC-40, Cape Can...
# 17  Tue Aug 26, 2025 7:30 PM CLT\nPad 1, Starbase,...
# 18  Tue Aug 26, 2025 2:53 PM CLT\nSLC-4E, Vandenbe...
# 19  Mon Aug 25, 2025 3:08 PM CLT\nCommercial LC-1,...
# 20  Sun Aug 24, 2025 2:45 AM CLT\nSLC-40, Cape Can...
# 21  Sat Aug 23, 2025 6:42 PM CLT\nRocket Lab LC-1A...
# 22  Fri Aug 22, 2025 1:04 PM CLT\nSLC-4E, Vandenbe...
# 23  Thu Aug 21, 2025 11:50 PM CLT\nLC-39A, Kennedy...
# 24  Thu Aug 21, 2025 5:32 AM CLT\nSite 35/1, Plese...
# 25  Wed Aug 20, 2025 1:13 PM CLT\nSite 31/6, Baiko...
# 26  Tue Aug 19, 2025 3:33 AM CLT\nSite 130, Jiuqua...
# 27  Mon Aug 18, 2025 12:26 PM CLT\nSLC-4E, Vandenb...
# 28  Sun Aug 17, 2025 10:15 AM CLT\nLC-9A, Taiyuan ...
# 29  Sun Aug 17, 2025 4:55 AM CLT\nLC-3, Xichang Sa...
# 30  Thu Aug 14, 2025 9:17 PM CLT\nSite 96, Jiuquan...
# 31  Thu Aug 14, 2025 8:29 AM CLT\nSLC-40, Cape Can...
# 32  Thu Aug 14, 2025 1:05 AM CLT\nSLC-4E, Vandenbe...
# 3        7,128 kN      3         4        58.0 m            4.2 m
# 4             NaN      4         0        31.0 m           3.35 m
# 5        7,607 kN      2         0        70.0 m            5.2 m
# 6        7,230 kN      2         4        50.0 m            4.2 m
# 7        7,607 kN      2         0        70.0 m            5.2 m
# 8          588 kN      4         0        19.0 m            1.4 m
# 9        5,923 kN      4         2       55.64 m            4.2 m
# 10       7,607 kN      2         0        70.0 m            5.2 m
# 11       7,607 kN      2         0        70.0 m            5.2 m
# 12         554 kN      3         0        22.0 m           1.35 m
# 13       7,607 kN      2         0        70.0 m            5.2 m
# 14       7,607 kN      2         0        70.0 m            5.2 m
# 15       7,607 kN      2         0        70.0 m            5.2 m
# 16       7,607 kN      2         0        70.0 m            5.2 m
# 17      74,400 kN      2       NaN       123.1 m            9.0 m
# 18       7,607 kN      2         0        70.0 m            5.2 m
# 19       4,894 kN      2         2       50.54 m            5.2 m
# 20       7,607 kN      2         0        70.0 m            5.2 m
# 21         224 kN      3         0        18.0 m            1.2 m
# 22       7,607 kN      2         0        70.0 m            5.2 m
# 23       7,607 kN      2         0        70.0 m            5.2 m
# 24       1,922 kN      2         0        42.7 m            3.0 m
# 25       4,550 kN      3         4       44.08 m           4.11 m
# 26            NaN      4         0        31.0 m           3.35 m
# 27       7,607 kN      2         0        70.0 m            5.2 m
# 28       7,230 kN      2         4        50.0 m            4.2 m
# 29       2,993 kN      3         0       46.97 m            3.8 m
# 30       2,880 kN      2         0        49.5 m           3.35 m
# 31       7,607 kN      2         0        70.0 m            5.2 m
# 32       7,607 kN      2         0        70.0 m            5.2 m
# 33      10,565 kN      3         4       53.66 m            5.2 m
# 34      13,006 kN      2         4        61.6 m            5.4 m
# 35       8,370 kN      2         2        62.0 m            5.4 m
# 36       7,607 kN      2         0        70.0 m            5.2 m
# 37            NaN      4         0        31.0 m           3.35 m
# 38         224 kN      3         0        18.0 m            1.2 m
# 39       5,000 kN      2         0        59.0 m            3.8 m
# 40       7,607 kN      2         0        70.0 m            5.2 m
# 41         490 kN      2         0        18.0 m              NaN
# 42       7,607 kN      2         0        70.0 m            5.2 m
# 43       7,607 kN      2         0        70.0 m            5.2 m
# 44         537 kN      4         0        19.8 m            1.4 m
# 45       7,887 kN      3         4        51.7 m            4.0 m
# 46       4,894 kN      2         2       50.54 m            5.2 m
# 47       7,607 kN      2         0        70.0 m            5.2 m
# 48            NaN      3       NaN        25.0 m            1.5 m
# 49         557 kN      4         0        21.0 m            1.2 m
# 50       7,230 kN      2         4        50.0 m            4.2 m
# 51       7,607 kN      2         0        70.0 m            5.2 m
# 52       7,607 kN      2         0        70.0 m            5.2 m
# 53       4,500 kN      4         0        35.0 m            3.3 m
# 54       4,550 kN      4         4       46.94 m           4.11 m
# 55       7,607 kN      2         0        70.0 m            5.2 m
# 56       7,607 kN      2         0        70.0 m            5.2 m
# 57       7,607 kN      2         0        70.0 m            5.2 m
# 58       7,607 kN      2         0        70.0 m            5.2 m
# 59       7,607 kN      2         0        70.0 m            5.2 m
#
#    Fairing Height      LEO_kg     GTO_kg  Payload_total_kg  Volumen_total_m3
# 0          13.0 m   22.800000   8.300000         31.100000                 0
# 1         15.59 m    7.500000   7.260077         14.760077                 0
# 2          13.0 m   22.800000   8.300000         31.100000                 0
# 3          12.4 m   12.000000   7.000000         19.000000                 0
# 4             NaN    1.500000   7.260077          8.760077                 0
# 5          13.0 m   22.800000   8.300000         31.100000                 0
# 6           5.7 m    5.000000   7.260077         12.260077                 0
# 7          13.0 m   22.800000   8.300000         31.100000                 0
# 8           2.5 m  400.000000   7.260077        407.260077                 0
# 9          9.78 m    7.500000   3.500000         11.000000                 0
# 10         13.0 m   22.800000   8.300000         31.100000                 0
# 11         13.0 m   22.800000   8.300000         31.100000                 0
# 12         4.37 m  350.000000   7.260077        357.260077                 0
# 13         13.0 m   22.800000   8.300000         31.100000                 0
# 14         13.0 m   22.800000   8.300000         31.100000                 0
# 15         13.0 m   22.800000   8.300000         31.100000                 0
# 16         13.0 m   22.800000   8.300000         31.100000                 0
# 17            NaN   35.000000   7.260077         42.260077                 0
# 18         13.0 m   22.800000   8.300000         31.100000                 0
# 19            NaN    9.800000   3.500000         13.300000                 0
# 20         13.0 m   22.800000   8.300000         31.100000                 0
# 21         4.05 m  320.000000   7.260077        327.260077                 0
# 22         13.0 m   22.800000   8.300000         31.100000                 0
# 23         13.0 m   22.800000   8.300000         31.100000                 0
# 24          2.9 m    3.800000   7.260077         11.060077                 0
# 25         8.36 m    8.020000   7.260077         15.280077                 0
# 26            NaN    2.000000   1.500000          3.500000                 0
# 27         13.0 m   22.800000   8.300000         31.100000                 0
# 28          5.7 m    5.000000   7.260077         12.260077                 0
# 29        11.74 m    4.200000   1.500000          5.700000                 0
# 30          5.0 m    6.000000   7.260077         13.260077                 0
# 31         13.0 m   22.800000   8.300000         31.100000                 0
# 32         13.0 m   22.800000   8.300000         31.100000                 0
# 33         20.5 m   15.000000   7.260077         22.260077                 0
# 34         15.5 m   24.600000  11.693000         36.293000                 0
# 35         20.0 m   10.350000   4.500000         14.850000                 0
# 36         13.0 m   22.800000   8.300000         31.100000                 0
# 37            NaN    1.500000   7.260077          8.760077                 0
# 38         4.05 m  320.000000   7.260077        327.260077                 0
# 39          5.2 m   12.000000   7.260077         19.260077                 0
# 40         13.0 m   22.800000   8.300000         31.100000                 0
# 41            NaN   53.501186   7.260077         60.761263                 0
# 42         13.0 m   22.800000   8.300000         31.100000                 0
# 43         13.0 m   22.800000   8.300000         31.100000                 0
# 44          3.4 m  300.000000   7.260077        307.260077                 0
# 45          7.8 m    5.000000   2.500000          7.500000                 0
# 46            NaN    9.800000   3.500000         13.300000                 0
# 47         13.0 m   22.800000   8.300000         31.100000                 0
# 48            NaN  305.000000   7.260077        312.260077                 0
# 49          2.2 m  300.000000   7.260077        307.260077                 0
# 50          5.7 m    5.000000   7.260077         12.260077                 0
# 51         13.0 m   22.800000   8.300000         31.100000                 0
# 52         13.0 m   22.800000   8.300000         31.100000                 0
# 53          9.0 m    2.300000   7.260077          9.560077                 0
# 54        11.43 m    7.500000   3.250000         10.750000                 0
# 55         13.0 m   22.800000   8.300000         31.100000                 0
# 56         13.0 m   22.800000   8.300000         31.100000                 0
# 57         13.0 m   22.800000   8.300000         31.100000                 0
# 58         13.0 m   22.800000   8.300000         31.100000                 0
# 59         13.0 m   22.800000   8.300000         31.100000                 0
